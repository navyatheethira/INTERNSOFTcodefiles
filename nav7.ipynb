# %% [markdown]
# <a href="https://colab.research.google.com/github/navyatheethira/INTERNSOFTcodefiles/blob/main/nav7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PART-1**
# **Installing and Using Pandas**

# %%
import pandas
pandas.__version__
# Out:
# '2.2.2'

# %% [markdown]
# **Introducing Pandas Objects**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Pandas Data Structures-**
# **Series, DataFrames, Index**

# %% [markdown]
# **Series**
# It's a single vector of data with an index that labels each element in vector

# %%
counts=pd.Series([632,1578,965,511])
counts
# Out:
# 0     632
# 1    1578
# 2     965
# 3     511
# dtype: int64

# %%
counts.values
# Out:
# array([ 632, 1578,  965,  511])

# %%
counts.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
Python=pd.Series([632,1578,965,511],
     index=['Variables','Operators','Functions','Error Handling'])
Python
# Out:
# Variables          632
# Operators         1578
# Functions          965
# Error Handling     511
# dtype: int64

# %%
Python['Functions']
# Out:
# 965

# %%
Python[0]
# Out:
# <ipython-input-8-eccbb71cc536>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Python[0]
# 632

# %%
Python.name='counts'
Python.index.name= 'Concepts'
Python
# Out:
# Concepts
# Variables          632
# Operators         1578
# Functions          965
# Error Handling     511
# Name: counts, dtype: int64

# %%
np.log(Python)
# Out:
# Concepts
# Variables         6.448889
# Operators         7.363914
# Functions         6.872128
# Error Handling    6.236370
# Name: counts, dtype: float64

# %%
Python[Python>1000]
# Out:
# Concepts
# Operators    1578
# Name: counts, dtype: int64

# %%
Python_dict={'Variables':632,'Operators':1578,'Functions':965,'Error Hnadling':511}
print(Python_dict)
pd.Series(Python_dict)
# Out:
# {'Variables': 632, 'Operators': 1578, 'Functions': 965, 'Error Hnadling': 511}
# Variables          632
# Operators         1578
# Functions          965
# Error Hnadling     511
# dtype: int64

# %% [markdown]
# **Series as Generalized Numpy Array & Specialized Dictionary**

# %% [markdown]
# **DataFrame : Bi-Dimensional Series with two or more indices**

# %%
data={"Province":['FL','FL','NH','NH','ZH'],
      "Year": [2002,2004,2006,2002,2004],
      "Literacy":[0.2,0.1,0.5,0.3,0.5]}
print(data)
data=pd.DataFrame(data)
data
# Out:
# {'Province': ['FL', 'FL', 'NH', 'NH', 'ZH'], 'Year': [2002, 2004, 2006, 2002, 2004], 'Literacy': [0.2, 0.1, 0.5, 0.3, 0.5]}
#   Province  Year  Literacy
# 0       FL  2002       0.2
# 1       FL  2004       0.1
# 2       NH  2006       0.5
# 3       NH  2002       0.3
# 4       ZH  2004       0.5

# %%
df=pd.DataFrame(data, columns=["Year","Province","Literacy"])
df
# Out:
#    Year Province  Literacy
# 0  2002       FL       0.2
# 1  2004       FL       0.1
# 2  2006       NH       0.5
# 3  2002       NH       0.3
# 4  2004       ZH       0.5

# %%
df['Values']=df.Year/df.Literacy
df
# Out:
#    Year Province  Literacy        Legend        Values
# 0  2002       FL       0.2  10010.000000  10010.000000
# 1  2004       FL       0.1  20040.000000  20040.000000
# 2  2006       NH       0.5   4012.000000   4012.000000
# 3  2002       NH       0.3   6673.333333   6673.333333
# 4  2004       ZH       0.5   4008.000000   4008.000000

# %%
df['Serie_Aligned']=pd.Series(range(5),index=[0,1,2,3,4])
df
# Out:
#    Year Province  Literacy        Legend        Values  Serie_Aligned
# 0  2002       FL       0.2  10010.000000  10010.000000              0
# 1  2004       FL       0.1  20040.000000  20040.000000              1
# 2  2006       NH       0.5   4012.000000   4012.000000              2
# 3  2002       NH       0.3   6673.333333   6673.333333              3
# 4  2004       ZH       0.5   4008.000000   4008.000000              4

# %%
df.to_dict()
# Out:
# {'Year': {0: 2002, 1: 2004, 2: 2006, 3: 2002, 4: 2004},
#  'Province': {0: 'FL', 1: 'FL', 2: 'NH', 3: 'NH', 4: 'ZH'},
#  'Literacy': {0: 0.2, 1: 0.1, 2: 0.5, 3: 0.3, 4: 0.5},
#  'Legend': {0: 10010.0,
#   1: 20040.0,
#   2: 4012.0,
#   3: 6673.333333333334,
#   4: 4008.0},
#  'Values': {0: 10010.0,
#   1: 20040.0,
#   2: 4012.0,
#   3: 6673.333333333334,
#   4: 4008.0},
#  'Serie_Aligned': {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}}

# %%
pd.DataFrame(df.to_dict())
# Out:
#    Year Province  Literacy        Legend        Values  Serie_Aligned
# 0  2002       FL       0.2  10010.000000  10010.000000              0
# 1  2004       FL       0.1  20040.000000  20040.000000              1
# 2  2006       NH       0.5   4012.000000   4012.000000              2
# 3  2002       NH       0.3   6673.333333   6673.333333              3
# 4  2004       ZH       0.5   4008.000000   4008.000000              4

# %% [markdown]
# **DataFrames as specialized dictionary**

# %% [markdown]
# From a list of dicts

# %%
values=[{'a':i,'b':10*i} for i in range(6)]
print(values)
pd.DataFrame(values)
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 10}, {'a': 2, 'b': 20}, {'a': 3, 'b': 30}, {'a': 4, 'b': 40}, {'a': 5, 'b': 50}]
#    a   b
# 0  0   0
# 1  1  10
# 2  2  20
# 3  3  30
# 4  4  40
# 5  5  50

# %%
pd.DataFrame([{'aa':1,'bb':3,'cc':6}])
# Out:
#    aa  bb  cc
# 0   1   3   6

# %% [markdown]
# From a 2-D numpy array

# %%
pd.DataFrame(np.random.randint(2,12),
            columns=['Sanon','Styles'],
             index=['a','b','c'])
# Out:
#    Sanon  Styles
# a      7       7
# b      7       7
# c      7       7
